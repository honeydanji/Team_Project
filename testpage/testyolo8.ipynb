# %% [markdown]
# ## yolo ver8 사용방법
# - 먼저 command 창에 python -m venv venv해서 가상 환경만들기
# - pip install ultralytics 해서 yolo 불러오기

# %% [markdown]
# - 사전학습 모델 "yolov8n.pt" (object detection) 가져와서 모델로 사용

# %%
from ultralytics import YOLO
import pandas as pd

model = YOLO('yolov8n.pt')

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# - model의 타입, 클래스 몇개있는 지 확인

# %%
type(model.names), len(model.names)
# Out:
# (dict, 80)

# %% [markdown]
# - model이 가지고 있는 클래스 확인 80개의 객체 탐지 가능

# %%
print(model.names)
# Out:
# {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'micr
# ...

# %% [markdown]
# - testImage 안에 있는 이미지들을 예측하고 저장

# %%
results = model.predict(source="testImage/", save=True)
# Out:
# image 1/4 c:\MainProject_local\testImage\1.jpg: 640x640 2 books, 136.4ms
# image 2/4 c:\MainProject_local\testImage\2.png: 640x640 2 suitcases, 114.7ms
# image 3/4 c:\MainProject_local\testImage\3.jpg: 640x416 (no detections), 84.8ms
# image 4/4 c:\MainProject_local\testImage\4.jpg: 480x640 2 toilets, 1 microwave, 99.0ms
# Speed: 3.5ms preprocess, 108.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to c:\MainProject_local\runs\detect\predict2

# %%
izone = model.predict(source="testImage2/",save=True)
# Out:
# image 1/4 c:\MainProject_local\testImage2\1.jpg: 640x416 11 persons, 1 potted plant, 3 teddy bears, 85.0ms
# image 2/4 c:\MainProject_local\testImage2\NewJeans-on-Twitter.jpg: 640x480 9 persons, 80.0ms
# image 3/4 c:\MainProject_local\testImage2\cat.jpg: 640x640 2 cats, 99.0ms
# image 4/4 c:\MainProject_local\testImage2\izone.jpg: 640x448 14 persons, 76.0ms
# Speed: 3.5ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to c:\MainProject_local\runs\detect\predict2

# %%
from PIL import Image
import matplotlib.pyplot as plt
import glob as gl

image_list = []
for filename in gl.glob('runs/detect/predict2/*.jpg'):
    im = Image.open(filename)
    image_list.append(im)

# 이미지를 순회하며 각각을 표시
for im in image_list:
    plt.figure()
    plt.imshow(im)
    plt.show()

# %% [markdown]
# - pillow install해서 이미지 보여주기

# %%
from PIL import Image

testimages = Image.open("runs/detect/predict/1.jpg")

display(testimages)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=564x564>

# %% [markdown]
# glob로 폴더에 있는 이미지 파일 리스트로 묶은 뒤 plt를 써서 각각 보여주기

# %%
from PIL import Image
import matplotlib.pyplot as plt
import glob as gl

image_list = []
for filename in gl.glob('runs/detect/predict/*.jpg'):
    im = Image.open(filename)
    image_list.append(im)

# 이미지를 순회하며 각각을 표시
for im in image_list:
    plt.figure()
    plt.imshow(im)
    plt.show()
