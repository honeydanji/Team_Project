# %%
import zipfile as zip
tools = zip.ZipFile("testZipImage\Tool_new.v5i.yolov8.zip")
tools.extractall("ziptools")

# %%
boxes = zip.ZipFile("testZipImage\Tool_new.v5i.yolov8.zip")
boxes.extractall("zipboxes")

# %%
from ultralytics import YOLO

model1 = YOLO('yolov8n.pt')

test1 =  model1.train(data="ziptools\data.yaml",epochs=100, patience=30, batch=32, imgsz=416 )
# Out:
# Ultralytics YOLOv8.0.158  Python-3.11.4 torch-2.0.1+cpu CPU (Intel Core(TM) i7-9700 3.00GHz)
# ...

# %%
type(model1.names), len(model1.names)

# %%
print(model1.names)
